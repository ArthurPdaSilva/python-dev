# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
from crewai import Agent, Task, Crew

# %% [markdown]
# ### Agentes
# - Pesquisador de Mercado
# - Analista de Tendências
# - Redator do Relatório

# %%
pesquisador = Agent(
    role="Pesquisador de Mercado",
    goal="Coletar e organizar informações relevantes sobre {sector}",
    backstory="""
    Você é um pesquisador experiente que analisa tendências de mercado e coleta
    dados relevantes sobre {sector}. Seu trabalho é garantir que todas as 
    informações estejam atualizadas e bem documentadas.
    """,
    allow_delegation=False,
    verbose=True
)

# %%
analista = Agent(
    role="Analista de Tendências",
    goal="Analisar os dados do setor {sector} e identificar padrões e oportunidades",
    backstory="""
    Você é um analista de mercado que examina os dados coletados para identificar
    tendências emergentes, oportunidades e ameaças no setor {sector}
    """,
    allow_delegation=False,
    verbose=True
)

# %%
redator = Agent(
    role="Redator de Relatórios",
    goal="Elaborar um relatório consolidado sobre a análise de mercado do setor {sector}.",
    backstory="""
    Você é um redator profissional que transforma anállises de mercado em um relatório
    estruturado e compreensível para tomadores de decisão.
    """,
    allow_delegation=False,
    verbose=True
)

# %%
coleta_dados = Task(
    description=(
        "1. Pesquisar e coletar informações atualizadas sobre {sector}."
        "2. Identificar os principais players, tendências e estatísticas do setor."
        "3. Organizar os dados de forma clara para análise"
    ),
    expected_output="Um documento estruturado contendo dados de mercado sobre {sector}",
    agent=pesquisador
)

# %%
analise_tendencias = Task(
    description=(
        "1. Examinar os dados coletados pelo Pesquisador de Mercado."
        "2. Identificar padrões, tendências emergentes e oportunidades no setor {sector}"
        "3. Elaborar uma análise detalhada destacando os principais pontos."
    ),
    expected_output="Um relatório com insights e tendências baseados nos dados do setor {sector}",
    agent=analista
)

# %%
redacao_relatorio = Task(
    description=(
        "1. Usar a análise de tendências para criar um relatório detalhado sobre {sector}."
        "2. Garantir que o relatório seja bem estruturado e compreensível."
        "3. Apresentar um resumo executivo e recomendações finais"
    ),
    expected_output="Um relatório de análise de mercado em formato Markdown, pronto para leitura e apresentação.",
    agent=redator
)

# %%
crew = Crew(
    agents = [pesquisador, analista, redator],
    tasks = [coleta_dados, analise_tendencias, redacao_relatorio],
    verbose = True
)

# %%
 crew
# Out:
# Crew(id=efd3022a-1e22-4733-9e9a-fb768e573335, process=Process.sequential, number_of_agents=3, number_of_tasks=3)

# %%
resultado = crew.kickoff(inputs={"sector": "Inteligência Artificial"})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: efd3022a-1e22-4733-9e9a-fb768e573335                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Pesquisador de Mercado
# ## Task: 1. Pesquisar e coletar informações atualizadas sobre Inteligência Artificial.2. Identificar os principais
# players, tendências e estatísticas do setor.3. Organizar os dados de forma clara para análise
# Output()
# [1m[95m# Agent:[00m [1m[92mPesquisador de Mercado[00m
# # Agent: Pesquisador de Mercado
# ## Task: 1. Pesquisar e coletar informações atualizadas sobre Inteligência Artificial.2. Identificar os principais
# players, tendências e estatísticas do setor.3. Organizar os dados de forma clara para análise
# [1m[95m# Agent:[00m [1m[92mPesquisador de Mercado[00m
# # Agent: Pesquisador de Mercado
# ## Task: 1. Pesquisar e coletar informações atualizadas sobre Inteligência Artificial.2. Identificar os principais
# players, tendências e estatísticas do setor.3. Organizar os dados de forma clara para análise
# [1m[95m# Agent:[00m [1m[92mPesquisador de Mercado[00m
#  Error details: maximum recursion depth exceeded
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────────── Task Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Failed                                                                                                    │
# │  Name: f8412d4c-5385-4184-8b85-2e8999cb8420                                                                     │
# │  Agent: Pesquisador de Mercado                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────────── Crew Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Failed                                                                                          │
# │  Name: crew                                                                                                     │
# │  ID: efd3022a-1e22-4733-9e9a-fb768e573335                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:1679, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1678 with self:
# -> 1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    1682         end,
#    1683         justify=justify,
#    1684         emoji=emoji,
#    1685         markup=markup,
#    1686         highlight=highlight,
#    1687     )
#    1688     for hook in render_hooks:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:1539, in Console._collect_renderables(self, objects, sep, end, justify, emoji, markup, highlight)
#    1537 if isinstance(renderable, str):
#    1538     append_text(
# -> 1539         self.render_str(
#    1540             renderable,
#    1541             emoji=emoji,
#    1542             markup=markup,
#    1543             highlight=highlight,
#    1544             highlighter=_highlighter,
#    1545         )
#    1546     )
#    1547 elif isinstance(renderable, Text):
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:1451, in Console.render_str(self, text, style, justify, overflow, emoji, markup, highlight, highlighter)
#    1450 if _highlighter is not None:
# -> 1451     highlight_text = _highlighter(str(rich_text))
#    1452     highlight_text.copy_styles(rich_text)
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\highlighter.py:38, in Highlighter.__call__(self, text)
#      37     raise TypeError(f"str or Text instance required, not {text!r}")
# ---> 38 self.highlight(highlight_text)
#      39 return highlight_text
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\highlighter.py:77, in RegexHighlighter.highlight(self, text)
#      76 for re_highlight in self.highlights:
# ---> 77     highlight_regex(re_highlight, style_prefix=self.base_style)
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\text.py:615, in Text.highlight_regex(self, re_highlight, style, style_prefix)
#     614 _Span = Span
# --> 615 plain = self.plain
#     616 if isinstance(re_highlight, str):
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\crewai\agent.py:404, in Agent.execute_task(self, task, context, tools)
#     403     else:
# --> 404         result = self._execute_without_timeout(task_prompt, task)
#     406 except TimeoutError as e:
#     407     # Propagate TimeoutError without retry
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\crewai\agent.py:500, in Agent._execute_without_timeout(self, task_prompt, task)
#     491 """Execute a task without a timeout.
#     492
#     493 Args:
#    (...)    498     The output of the agent.
#     499 """
# --> 500 return self.agent_executor.invoke(
#     501     {
#     502         "input": task_prompt,
#     503         "tool_names": self.agent_executor.tools_names,
#     504         "tools": self.agent_executor.tools_description,
#     505         "ask_for_human_input": task.human_input,
#     506     }
#     507 )["output"]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:123, in CrewAgentExecutor.invoke(self, inputs)
#     122     else:
# --> 123         raise e
#     125 if self.ask_for_human_input:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:110, in CrewAgentExecutor.invoke(self, inputs)
#     109 try:
# --> 110     formatted_answer = self._invoke_loop()
#     111 except AssertionError:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:228, in CrewAgentExecutor._invoke_loop(self)
#     227 assert isinstance(formatted_answer, AgentFinish)
# --> 228 self._show_logs(formatted_answer)
#     229 return formatted_answer
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:280, in CrewAgentExecutor._show_logs(self, formatted_answer)
#     279     raise ValueError("Agent cannot be None")
# --> 280 show_agent_logs(
#     281     printer=self._printer,
#     282     agent_role=self.agent.role,
#     283     formatted_answer=formatted_answer,
#     284     verbose=self.agent.verbose
#     285     or (hasattr(self, "crew") and getattr(self.crew, "verbose", False)),
#     286 )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\crewai\utilities\agent_utils.py:411, in show_agent_logs(printer, agent_role, formatted_answer, task_description, verbose)
#     409 else:
#     410     # Execution logs
# --> 411     printer.print(
#     412         content=f"\n\n\033\033# Agent:\033 \033\033{agent_role}\033"
#     413     )
#     415     if isinstance(formatted_answer, AgentAction):
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\crewai\utilities\printer.py:35, in Printer.print(self, content, color)
#      34 else:
# ---> 35     print(content)
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\file_proxy.py:43, in FileProxy.write(self, text)
#      42 console = self.__console
# ---> 43 with console:
#      44     output = Text("\n").join(
#      45         self.__ansi_decoder.decode_line(line) for line in lines
#      46     )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     863 """Exit buffer context."""
# --> 864 self._exit_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2033 from .jupyter import display
# -> 2035 display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036 del self._buffer[:]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      88 """Publish a display-data message
#      89
#      90 Parameters
#    (...)    101     If True, send an update_display_data message instead of display_data.
#     102 """
# --> 103 self._flush_streams()
#     104 if metadata is None:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
# ---> 66 sys.stdout.flush()
#      67 sys.stderr.flush()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     863 """Exit buffer context."""
# --> 864 self._exit_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2033 from .jupyter import display
# -> 2035 display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036 del self._buffer[:]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      88 """Publish a display-data message
#      89
#      90 Parameters
#    (...)    101     If True, send an update_display_data message instead of display_data.
#     102 """
# --> 103 self._flush_streams()
#     104 if metadata is None:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
# ---> 66 sys.stdout.flush()
#      67 sys.stderr.flush()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#
#     [... skipping similar frames: Console.__exit__ at line 864 (267 times), Console._check_buffer at line 2019 (267 times), Console._exit_buffer at line 822 (267 times), Console._write_buffer at line 2035 (267 times), ZMQDisplayPublisher._flush_streams at line 66 (266 times), display at line 91 (266 times), display at line 285 (266 times), FileProxy.flush at line 53 (266 times), Console.print at line 1678 (266 times), ZMQDisplayPublisher.publish at line 103 (266 times), publish_display_data at line 73 (266 times)]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      88 """Publish a display-data message
#      89
#      90 Parameters
#    (...)    101     If True, send an update_display_data message instead of display_data.
#     102 """
# --> 103 self._flush_streams()
#     104 if metadata is None:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
# ---> 66 sys.stdout.flush()
#      67 sys.stderr.flush()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     863 """Exit buffer context."""
# --> 864 self._exit_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2033 from .jupyter import display
# -> 2035 display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036 del self._buffer[:]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2102, in Console._render_buffer(self, buffer)
#    2101 legacy_windows = self.legacy_windows
# -> 2102 not_terminal = not self.is_terminal
#    2103 if self.no_color and color_system:
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\formatters.py:282, in catch_format_error(method, self, *args, **kwargs)
#     281 try:
# --> 282     r = method(self, *args, **kwargs)
#     283 except NotImplementedError:
#     284     # don't warn on NotImplementedErrors
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\formatters.py:975, in IPythonDisplayFormatter.__call__(self, obj)
#     974 try:
# --> 975     printer = self.lookup(obj)
#     976 except KeyError:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\formatters.py:456, in BaseFormatter.lookup(self, obj)
#     455 # then lookup by type
# --> 456 return self.lookup_by_type(_get_type(obj))
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\formatters.py:486, in BaseFormatter.lookup_by_type(self, typ)
#     485 for cls in pretty._get_mro(typ):
# --> 486     if cls in self.type_printers or self._in_deferred_types(cls):
#     487         return self.type_printers[cls]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\formatters.py:623, in BaseFormatter._in_deferred_types(self, cls)
#     622 key = (mod, name)
# --> 623 if key in self.deferred_printers:
#     624     # Move the printer over to the regular registry.
#     625     printer = self.deferred_printers.pop(key)
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\traitlets\traitlets.py:687, in TraitType.__get__(self, obj, cls)
#     686 else:
# --> 687     return t.cast(G, self.get(obj, cls))
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\traitlets\traitlets.py:666, in TraitType.get(self, obj, cls)
#     665 else:
# --> 666     return t.cast(G, value)
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\interactiveshell.py:2178, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2177     else:
# -> 2178         stb = self.InteractiveTB.structured_traceback(
#    2179             etype, value, tb, tb_offset=tb_offset
#    2180         )
#    2182 except Exception:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\ultratb.py:1182, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1181     self.tb = etb
# -> 1182 return FormattedTB.structured_traceback(
#    1183     self, etype, evalue, etb, tb_offset, context
#    1184 )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\ultratb.py:1053, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1051 if mode in self.verbose_modes:
#    1052     # Verbose modes need a full traceback
# -> 1053     return VerboseTB.structured_traceback(
#    1054         self, etype, evalue, etb, tb_offset, context
#    1055     )
#    1056 elif mode == "Docs":
#    1057     # return DocTB
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\ultratb.py:861, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     860 """Return a nice text document describing the traceback."""
# --> 861 formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     862     etype, evalue, etb, context, tb_offset
#     863 )
#     865 termsize = min(75, get_terminal_size()[0])
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\ultratb.py:745, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     744 assert isinstance(tb_offset, int)
# --> 745 head = self.prepare_header(str(etype), self.long_header)
#     746 records = self.get_records(etb, context, tb_offset) if etb else []
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\ultratb.py:661, in VerboseTB.prepare_header(self, etype, long_version)
#     660 def prepare_header(self, etype: str, long_version: bool = False) -> str:
# --> 661     width = min(75, get_terminal_size()[0])
#     662     if long_version:
#     663         # Header with the exception type, python version, and date
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\file_proxy.py:44, in FileProxy.write(self, text)
#      43 with console:
# ---> 44     output = Text("\n").join(
#      45         self.__ansi_decoder.decode_line(line) for line in lines
#      46     )
#      47     console.print(output)
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\text.py:806, in Text.join(self, lines)
#     804 _Span = Span
# --> 806 for text in iter_text():
#     807     extend_text(text._text)
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\text.py:793, in Text.join.<locals>.iter_text()
#     792 if self.plain:
# --> 793     for last, line in loop_last(lines):
#     794         yield line
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\_loop.py:22, in loop_last(values)
#      21 try:
# ---> 22     previous_value = next(iter_values)
#      23 except StopIteration:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\file_proxy.py:45, in <genexpr>(.0)
#      43 with console:
#      44     output = Text("\n").join(
# ---> 45         self.__ansi_decoder.decode_line(line) for line in lines
#      46     )
#      47     console.print(output)
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\crewai\agent.py:404, in Agent.execute_task(self, task, context, tools)
#     403     else:
# --> 404         result = self._execute_without_timeout(task_prompt, task)
#     406 except TimeoutError as e:
#     407     # Propagate TimeoutError without retry
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\crewai\agent.py:500, in Agent._execute_without_timeout(self, task_prompt, task)
#     491 """Execute a task without a timeout.
#     492
#     493 Args:
#    (...)    498     The output of the agent.
#     499 """
# --> 500 return self.agent_executor.invoke(
#     501     {
#     502         "input": task_prompt,
#     503         "tool_names": self.agent_executor.tools_names,
#     504         "tools": self.agent_executor.tools_description,
#     505         "ask_for_human_input": task.human_input,
#     506     }
#     507 )["output"]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:123, in CrewAgentExecutor.invoke(self, inputs)
#     122     else:
# --> 123         raise e
#     125 if self.ask_for_human_input:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:110, in CrewAgentExecutor.invoke(self, inputs)
#     109 try:
# --> 110     formatted_answer = self._invoke_loop()
#     111 except AssertionError:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:228, in CrewAgentExecutor._invoke_loop(self)
#     227 assert isinstance(formatted_answer, AgentFinish)
# --> 228 self._show_logs(formatted_answer)
#     229 return formatted_answer
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:280, in CrewAgentExecutor._show_logs(self, formatted_answer)
#     279     raise ValueError("Agent cannot be None")
# --> 280 show_agent_logs(
#     281     printer=self._printer,
#     282     agent_role=self.agent.role,
#     283     formatted_answer=formatted_answer,
#     284     verbose=self.agent.verbose
#     285     or (hasattr(self, "crew") and getattr(self.crew, "verbose", False)),
#     286 )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\crewai\utilities\agent_utils.py:411, in show_agent_logs(printer, agent_role, formatted_answer, task_description, verbose)
#     409 else:
#     410     # Execution logs
# --> 411     printer.print(
#     412         content=f"\n\n\033\033# Agent:\033 \033\033{agent_role}\033"
#     413     )
#     415     if isinstance(formatted_answer, AgentAction):
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\crewai\utilities\printer.py:35, in Printer.print(self, content, color)
#      34 else:
# ---> 35     print(content)
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\file_proxy.py:43, in FileProxy.write(self, text)
#      42 console = self.__console
# ---> 43 with console:
#      44     output = Text("\n").join(
#      45         self.__ansi_decoder.decode_line(line) for line in lines
#      46     )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     863 """Exit buffer context."""
# --> 864 self._exit_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2033 from .jupyter import display
# -> 2035 display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036 del self._buffer[:]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      88 """Publish a display-data message
#      89
#      90 Parameters
#    (...)    101     If True, send an update_display_data message instead of display_data.
#     102 """
# --> 103 self._flush_streams()
#     104 if metadata is None:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
# ---> 66 sys.stdout.flush()
#      67 sys.stderr.flush()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     863 """Exit buffer context."""
# --> 864 self._exit_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2033 from .jupyter import display
# -> 2035 display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036 del self._buffer[:]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      88 """Publish a display-data message
#      89
#      90 Parameters
#    (...)    101     If True, send an update_display_data message instead of display_data.
#     102 """
# --> 103 self._flush_streams()
#     104 if metadata is None:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
# ---> 66 sys.stdout.flush()
#      67 sys.stderr.flush()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#
#     [... skipping similar frames: Console.__exit__ at line 864 (266 times), Console._check_buffer at line 2019 (266 times), Console._exit_buffer at line 822 (266 times), Console._write_buffer at line 2035 (266 times), display at line 91 (266 times), ZMQDisplayPublisher._flush_streams at line 66 (265 times), display at line 285 (265 times), FileProxy.flush at line 53 (265 times), Console.print at line 1678 (265 times), ZMQDisplayPublisher.publish at line 103 (265 times), publish_display_data at line 73 (265 times)]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      88 """Publish a display-data message
#      89
#      90 Parameters
#    (...)    101     If True, send an update_display_data message instead of display_data.
#     102 """
# --> 103 self._flush_streams()
#     104 if metadata is None:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
# ---> 66 sys.stdout.flush()
#      67 sys.stderr.flush()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     863 """Exit buffer context."""
# --> 864 self._exit_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2033 from .jupyter import display
# -> 2035 display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036 del self._buffer[:]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:278, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     277 else:
# --> 278     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     279     if not format_dict:
#     280         # nothing to display (e.g. _ipython_display_ took over)
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\formatters.py:204, in DisplayFormatter.format(self, obj, include, exclude)
#     202 md_dict = {}
# --> 204 if self.ipython_display_formatter(obj):
#     205     # object handled itself, don't proceed
#     206     return {}, {}
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\decorator.py:235, in decorate.<locals>.fun(*args, **kw)
#     234     args, kw = fix(args, kw, sig)
# --> 235 return caller(func, *(extras + args), **kw)
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\formatters.py:290, in catch_format_error(method, self, *args, **kwargs)
#     289 if ip is not None:
# --> 290     ip.showtraceback(exc_info)
#     291 else:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\interactiveshell.py:2183, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2182 except Exception:
# -> 2183     print(
#    2184         "Unexpected exception formatting exception. Falling back to standard exception"
#    2185     )
#    2186     traceback.print_exc()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\file_proxy.py:43, in FileProxy.write(self, text)
#      42 console = self.__console
# ---> 43 with console:
#      44     output = Text("\n").join(
#      45         self.__ansi_decoder.decode_line(line) for line in lines
#      46     )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     863 """Exit buffer context."""
# --> 864 self._exit_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2031, in Console._write_buffer(self)
#    2029         self._record_buffer.extend(self._buffer[:])
# -> 2031 if self._buffer_index == 0:
#    2032     if self.is_jupyter:  # pragma: no cover
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\formatters.py:282, in catch_format_error(method, self, *args, **kwargs)
#     281 try:
# --> 282     r = method(self, *args, **kwargs)
#     283 except NotImplementedError:
#     284     # don't warn on NotImplementedErrors
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\formatters.py:975, in IPythonDisplayFormatter.__call__(self, obj)
#     974 try:
# --> 975     printer = self.lookup(obj)
#     976 except KeyError:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\formatters.py:456, in BaseFormatter.lookup(self, obj)
#     455 # then lookup by type
# --> 456 return self.lookup_by_type(_get_type(obj))
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\formatters.py:486, in BaseFormatter.lookup_by_type(self, typ)
#     485 for cls in pretty._get_mro(typ):
# --> 486     if cls in self.type_printers or self._in_deferred_types(cls):
#     487         return self.type_printers[cls]
#
# ...
#    2036     del self._buffer[:]
#    2037 else:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1676     crop = False
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#    1688     for hook in render_hooks:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     862 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     863     """Exit buffer context."""
# --> 864     self._exit_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     820 """Leave buffer context, and render content if required."""
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2016     return
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#    2021     self.on_broken_pipe()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2032 if self.is_jupyter:  # pragma: no cover
#    2033     from .jupyter import display
# -> 2035     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036     del self._buffer[:]
#    2037 else:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1676     crop = False
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#    1688     for hook in render_hooks:
#
#     [... skipping similar frames: Console.__exit__ at line 864 (266 times), Console._check_buffer at line 2019 (266 times), Console._exit_buffer at line 822 (266 times), Console._write_buffer at line 2035 (266 times), display at line 91 (266 times), ZMQDisplayPublisher._flush_streams at line 66 (265 times), display at line 285 (265 times), FileProxy.flush at line 53 (265 times), Console.print at line 1678 (265 times), ZMQDisplayPublisher.publish at line 103 (265 times), publish_display_data at line 73 (265 times)]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1676     crop = False
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#    1688     for hook in render_hooks:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     862 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     863     """Exit buffer context."""
# --> 864     self._exit_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     820 """Leave buffer context, and render content if required."""
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2016     return
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#    2021     self.on_broken_pipe()
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2032 if self.is_jupyter:  # pragma: no cover
#    2033     from .jupyter import display
# -> 2035     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036     del self._buffer[:]
#    2037 else:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\display_functions.py:278, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     276     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     277 else:
# --> 278     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     279     if not format_dict:
#     280         # nothing to display (e.g. _ipython_display_ took over)
#     281         continue
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\formatters.py:204, in DisplayFormatter.format(self, obj, include, exclude)
#     201 format_dict = {}
#     202 md_dict = {}
# --> 204 if self.ipython_display_formatter(obj):
#     205     # object handled itself, don't proceed
#     206     return {}, {}
#     208 format_dict, md_dict = self.mimebundle_formatter(obj, include=include, exclude=exclude)
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\decorator.py:235, in decorate.<locals>.fun(*args, **kw)
#     233 if not kwsyntax:
#     234     args, kw = fix(args, kw, sig)
# --> 235 return caller(func, *(extras + args), **kw)
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\formatters.py:290, in catch_format_error(method, self, *args, **kwargs)
#     288 ip = get_ipython()
#     289 if ip is not None:
# --> 290     ip.showtraceback(exc_info)
#     291 else:
#     292     traceback.print_exception(*exc_info)
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\interactiveshell.py:2166, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2161         return False
#    2162     return isinstance(
#    2163         val, BaseExceptionGroup
#    2164     ) or contains_exceptiongroup(val.__context__)
# -> 2166 if contains_exceptiongroup(value):
#    2167     # fall back to native exception formatting until ultratb
#    2168     # supports exception groups
#    2169     traceback.print_exc()
#    2170 else:
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\interactiveshell.py:2164, in InteractiveShell.showtraceback.<locals>.contains_exceptiongroup(val)
#    2160 if val is None:
#    2161     return False
#    2162 return isinstance(
#    2163     val, BaseExceptionGroup
# -> 2164 ) or contains_exceptiongroup(val.__context__)
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\interactiveshell.py:2164, in InteractiveShell.showtraceback.<locals>.contains_exceptiongroup(val)
#    2160 if val is None:
#    2161     return False
#    2162 return isinstance(
#    2163     val, BaseExceptionGroup
# -> 2164 ) or contains_exceptiongroup(val.__context__)
#
#     [... skipping similar frames: InteractiveShell.showtraceback.<locals>.contains_exceptiongroup at line 2164 (1 times)]
#
# File ~\OneDrive\Documentos\GitHub\python-dev\crewai\crewai-analise-de-mercado\.venv\Lib\site-packages\IPython\core\interactiveshell.py:2164, in InteractiveShell.showtraceback.<locals>.contains_exceptiongroup(val)
#    2160 if val is None:
#    2161     return False
#    2162 return isinstance(
#    2163     val, BaseExceptionGroup
# -> 2164 ) or contains_exceptiongroup(val.__context__)
#
# RecursionError: maximum recursion depth exceeded

# %%
print(resultado.raw)

# %%
from IPython.display import display, Markdown

# %%
display(Markdown(str(resultado))) # Fazendo o display do resultado em Markdown

# %%
import pdfkit

with open("artigo.md", "w", encoding="utf-8") as file:
    file.write(str(resultado))

import markdown

html = markdown.markdown(str(resultado))
with open("artigo.html", "w", encoding="utf-8") as file:
    file.write(html)
